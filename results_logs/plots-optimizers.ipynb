# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import sys
import  pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0,'/content/drive/MyDrive/ColabNotebooks/')

# %%
df_SWA = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/widerestnet-SWA.txt", sep =",")

# %%
df_SGD = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/widerestnet-SGD.txt", sep =",")

# %%
df_SAM = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/widerestnet-SAM.txt", sep =",")

# %%
df_GSAM = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/widerestnet-GSAM.txt", sep =",")

# %%
df_LION= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/widerestnet-lion.txt", sep =",")

# %%
df_LIONv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/inceptionv3-lion.txt", sep =",")

# %%
df_GSAMv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/inceptionv3-gsam.txt", sep =",")

# %%
GSAMv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/gsam.txt", sep =",")

# %%
LIONv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/lion.txt", sep =",")

# %%
SAMv3 = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/sam.txt", sep =",")

# %%
SWAv3 = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/swa.txt", sep =",")

# %%
SGDv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/sgd.txt", sep =",")

# %%
df_SWAv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/inceptionv3-SWA.txt", sep =",")

# %%
df_SGDv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/inceptionv3-sgd.txt", sep =",")

# %%
LIONv3['accuracy_train'] = LIONv3['accuracy_train'] * 100
SAMv3['accuracy_train'] = SAMv3['accuracy_train'] * 100
SWAv3['accuracy_train'] = SWAv3['accuracy_train'] * 100
SGDv3['accuracy_train'] = SGDv3['accuracy_train'] * 100

# %%
SAMv3['accuracy_train'] = SAMv3['accuracy_train'] * 100

# %%
df_LIONv3['accuracy_train'] = df_LIONv3['accuracy_train'] * 100
df_SWAv3['accuracy_train'] = df_SWAv3['accuracy_train'] * 100
df_SGDv3['accuracy_train'] = df_SGDv3['accuracy_train'] * 100

# %%
df_SWA['accuracy_train'] = df_SWA['accuracy_train'] * 100
df_SGD['accuracy_train'] = df_SGD['accuracy_train'] * 100
df_SAM['accuracy_train'] = df_SAM['accuracy_train'] * 100
df_LION['accuracy_train'] = df_LION['accuracy_train'] * 100
# utils zapisuja o 100x wartosc nizsza, ze wzlegdu na rozne zwracane wartosci optimizerow. w GSAM wartosc jest poprawna

# %%
plt.figure(figsize=(10, 6))

plt.plot(SWAv3['epoch'], SWAv3['accuracy_train'], label='SWA')
plt.plot(SGDv3['epoch'], SGDv3['accuracy_train'], label='SGD')
plt.plot(df_SAM['epoch'], df_SAM['accuracy_train'], label='SAM')
plt.plot(GSAMv3['epoch'], GSAMv3['accuracy_train'], label='GSAM')
plt.plot(LIONv3['epoch'], LIONv3['accuracy_train'], label='LION')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_SWA['epoch'], df_SWA['accuracy_valid'], label='SWA')
plt.plot(df_SGD['epoch'], df_SGD['accuracy_valid'], label='SGD')
plt.plot(df_SAM['epoch'], df_SAM['accuracy_valid'], label='SAM')
plt.plot(df_LION['epoch'], df_LION['accuracy_valid'], label='LION')
plt.plot(df_GSAM['epoch'], df_GSAM['accuracy_valid'], label='GSAM')
plt.plot(SWAv3['epoch'], SWAv3['accuracy_valid'], label='SAM')
plt.plot(SAMv3['epoch'], SAMv3['accuracy_valid'], label='SWAv3')
plt.plot(SGDv3['epoch'], SGDv3['accuracy_valid'], label='SGDv3')
plt.plot(LIONv3['epoch'], LIONv3['accuracy_valid'], label='LIONv3')
plt.plot(GSAMv3['epoch'], GSAMv3['accuracy_valid'], label='GSAMv3')

SAMv3
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_SWA['epoch'], df_SWA['loss_train'], label='SWA')
plt.plot(df_SGD['epoch'], df_SGD['loss_train'], label='SGD')
plt.plot(df_SAM['epoch'], df_SAM['loss_train'], label='SAM')
plt.plot(df_LION['epoch'], df_LION['loss_train'], label='LION')
plt.plot(df_GSAM['epoch'], df_GSAM['loss_train'], label='GSAM')
plt.plot(SWAv3['epoch'], SWAv3['loss_train'], label='SAM')
plt.plot(SAMv3['epoch'], SAMv3['loss_train'], label='SWAv3')
plt.plot(SGDv3['epoch'], SGDv3['loss_train'], label='SGDv3')
plt.plot(LIONv3['epoch'], LIONv3['loss_train'], label='LIONv3')
plt.plot(GSAMv3['epoch'], GSAMv3['loss_train'], label='GSAMv3')

SAMv3
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_LIONv3['epoch'], df_LIONv3['accuracy_train'], label='lion')
plt.plot(df_SWAv3['epoch'], df_SWAv3['accuracy_train'], label='swa')
plt.plot(df_GSAMv3['epoch'], df_GSAMv3['accuracy_train'], label='gsam')
plt.plot(df_SGDv3['epoch'], df_SGDv3['accuracy_train'], label='sgd')


plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_SWA['epoch'], df_SWA['accuracy_valid'], label='SWA')
plt.plot(df_SGD['epoch'], df_SGD['accuracy_valid'], label='SGD')
plt.plot(df_SAM['epoch'], df_SAM['accuracy_valid'], label='SAM')
plt.plot(df_GSAM['epoch'], df_GSAM['accuracy_valid'], label='GSAM')
plt.plot(df_LION['epoch'], df_LION['accuracy_valid'], label='LION')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('valid accuracy widerestnet')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(GSAMv3['epoch'], GSAMv3['accuracy_valid'], label='GSAM')
plt.plot(LIONv3['epoch'], LIONv3['accuracy_valid'], label='LION')
plt.plot(SWAv3['epoch'], SWAv3['accuracy_valid'], label='SWA')
plt.plot(SGDv3['epoch'], SGDv3['accuracy_valid'], label='SGD')
plt.plot(SAMv3['epoch'], SAMv3['accuracy_valid'], label='SAM')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
df = SAMv3


plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['accuracy_train'], label='Accuracy Train')
plt.plot(df['epoch'], df['accuracy_valid'], label='Accuracy Valid')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
plt.plot(df['epoch'], df['loss_valid'], color='r', label='Loss Valid')

plt.plot(df['epoch'], df['loss_train'], color='g', label='Loss Train')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.grid(True)
plt.show()



plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['lr'])

plt.xlabel('Epoch')
plt.ylabel('learning rate')
plt.legend()

plt.xlim(0, 50)

plt.grid(True)
plt.show()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
