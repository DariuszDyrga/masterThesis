# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import  pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0,'/content/drive/MyDrive/ColabNotebooks/')

# %%
vgg= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/vgg16/vgg-Lion.txt", sep =",")

# %%
mobilenet= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/mobilenet/mobilenet-Lion.txt", sep =",")

# %%
inceptionv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/inceptionv3/inception-Lion.txt", sep =",")

# %%
widerestnet =  pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/widerestnet/widerestnet-LION.txt", sep =",")

# %%
vit = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/vit224/vit-lion-224.txt")

# %%
vit['accuracy_train'] = vit['accuracy_train'] * 100
vgg['accuracy_train'] = vgg['accuracy_train'] * 100
mobilenet['accuracy_train'] = mobilenet['accuracy_train'] * 100
inceptionv3['accuracy_train'] = inceptionv3['accuracy_train'] * 100
widerestnet['accuracy_train'] = widerestnet['accuracy_train'] * 100

# %%
plt.figure(figsize=(10, 6))

plt.plot(vit['epoch'], vit['accuracy_train'], label='ViT')
plt.plot(vgg['epoch'], vgg['accuracy_train'], label='VGG')
plt.plot(mobilenet['epoch'], mobilenet['accuracy_train'], label='MobileNet')
plt.plot(inceptionv3['epoch'], inceptionv3['accuracy_train'], label='InceptionV3')
plt.plot(widerestnet['epoch'], widerestnet['accuracy_train'], label='WideRestNet')

plt.xlabel('Epoch')
plt.ylabel('Accuracy train')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(vit['epoch'], vit['accuracy_valid'], label='ViT')
plt.plot(vgg['epoch'], vgg['accuracy_valid'], label='VGG')
plt.plot(mobilenet['epoch'], mobilenet['accuracy_valid'], label='MobileNet')
plt.plot(inceptionv3['epoch'], inceptionv3['accuracy_valid'], label='InceptionV3')
plt.plot(widerestnet['epoch'], widerestnet['accuracy_valid'], label='WideRestNet')

plt.xlabel('Epoch')
plt.ylabel('Accuracy valid')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(vit['epoch'], vit['loss_train'], label='ViT')
plt.plot(vgg['epoch'], vgg['loss_train'], label='VGG')
plt.plot(mobilenet['epoch'], mobilenet['loss_train'], label='MobileNet')
plt.plot(inceptionv3['epoch'], inceptionv3['loss_train'], label='InceptionV3')
plt.plot(widerestnet['epoch'], widerestnet['loss_train'], label='WideRestNet')

plt.xlabel('Epoch')
plt.ylabel('Loss train')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(vit['epoch'], vit['loss_valid'], label='ViT')
plt.plot(vgg['epoch'], vgg['loss_valid'], label='VGG')
plt.plot(mobilenet['epoch'], mobilenet['loss_valid'], label='MobileNet')
plt.plot(inceptionv3['epoch'][2:], inceptionv3['loss_valid'][2:], label='InceptionV3')
plt.plot(widerestnet['epoch'], widerestnet['loss_valid'], label='WideRestNet')

plt.xlabel('Epoch')
plt.ylabel('Loss valid')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(vit['epoch'], vit['lr'], label='ViT')
plt.plot(vgg['epoch'], vgg['lr'], label='VGG')
plt.plot(mobilenet['epoch'], mobilenet['lr'], label='MobileNet')
plt.plot(inceptionv3['epoch'], inceptionv3['lr'], label='InceptionV3')
plt.plot(widerestnet['epoch'], widerestnet['lr'], label='WideRestNet')

plt.xlabel('Epoch')
plt.ylabel('Learning rate')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()
