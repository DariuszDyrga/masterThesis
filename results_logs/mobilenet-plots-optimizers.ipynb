# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import sys
import  pandas as pd
import matplotlib.pyplot as plt

sys.path.insert(0,'/content/drive/MyDrive/ColabNotebooks/')

# %%
SGDv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/mobilenet/mobilenet-SGD.txt", sep =",")

# %%
SWAv3 = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/mobilenet/mobilenet-SWA.txt", sep =",")

# %%
SAMv3 = pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/mobilenet/mobilenet-SAM.txt", sep =",")

# %%
GSAMv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/mobilenet/mobilenet-GSAM.txt", sep =",")

# %%
LIONv3= pd.read_csv("/content/drive/MyDrive/ColabNotebooks/results_logs/learning-history/75/mobilenet/mobilenet-Lion.txt", sep =",")

# %%
LIONv3['accuracy_train'] = LIONv3['accuracy_train'] * 100
SAMv3['accuracy_train'] = SAMv3['accuracy_train'] * 100
SWAv3['accuracy_train'] = SWAv3['accuracy_train'] * 100
SGDv3['accuracy_train'] = SGDv3['accuracy_train'] * 100

# %%
plt.figure(figsize=(10, 6))

plt.plot(SWAv3['epoch'], SWAv3['accuracy_train'], label='SWA')
plt.plot(SGDv3['epoch'], SGDv3['accuracy_train'], label='SGD')
plt.plot(SAMv3['epoch'], SAMv3['accuracy_train'], label='SAM')
plt.plot(GSAMv3['epoch'], GSAMv3['accuracy_train'], label='GSAM')
plt.plot(LIONv3['epoch'], LIONv3['accuracy_train'], label='LION')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(SWAv3['epoch'], SWAv3['accuracy_valid'], label='SWA')
plt.plot(SAMv3['epoch'], SAMv3['accuracy_valid'], label='SAM')
plt.plot(SGDv3['epoch'], SGDv3['accuracy_valid'], label='SGD')
plt.plot(LIONv3['epoch'], LIONv3['accuracy_valid'], label='LION')
plt.plot(GSAMv3['epoch'], GSAMv3['accuracy_valid'], label='GSAM')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(SWAv3['epoch'], SWAv3['loss_train'], label='SWA')
plt.plot(SAMv3['epoch'], SAMv3['loss_train'], label='SAM')
plt.plot(SGDv3['epoch'], SGDv3['loss_train'], label='SGD')
plt.plot(LIONv3['epoch'], LIONv3['loss_train'], label='LION')
plt.plot(GSAMv3['epoch'], GSAMv3['loss_train'], label='GSAM')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(SWAv3['epoch'], SWAv3['loss_valid'], label='SWA')
plt.plot(SAMv3['epoch'], SAMv3['loss_valid'], label='SAM')
plt.plot(SGDv3['epoch'], SGDv3['loss_valid'], label='SGD')
plt.plot(LIONv3['epoch'], LIONv3['loss_valid'], label='LION')
plt.plot(GSAMv3['epoch'], GSAMv3['loss_valid'], label='GSAM')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_LIONv3['epoch'], df_LIONv3['accuracy_train'], label='lion')
plt.plot(df_SWAv3['epoch'], df_SWAv3['accuracy_train'], label='swa')
plt.plot(df_GSAMv3['epoch'], df_GSAMv3['accuracy_train'], label='gsam')
plt.plot(df_SGDv3['epoch'], df_SGDv3['accuracy_train'], label='sgd')


plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-b964aa0b531b> in <cell line: 3>()
#       1 plt.figure(figsize=(10, 6))
#       2
# ----> 3 plt.plot(df_LIONv3['epoch'], df_LIONv3['accuracy_train'], label='lion')
#       4 plt.plot(df_SWAv3['epoch'], df_SWAv3['accuracy_train'], label='swa')
#       5 plt.plot(df_GSAMv3['epoch'], df_GSAMv3['accuracy_train'], label='gsam')
#
# NameError: name 'df_LIONv3' is not defined

# %%
plt.figure(figsize=(10, 6))

plt.plot(df_SWA['epoch'], df_SWA['accuracy_valid'], label='SWA')
plt.plot(df_SGD['epoch'], df_SGD['accuracy_valid'], label='SGD')
plt.plot(df_SAM['epoch'], df_SAM['accuracy_valid'], label='SAM')
plt.plot(df_GSAM['epoch'], df_GSAM['accuracy_valid'], label='GSAM')
plt.plot(df_LION['epoch'], df_LION['accuracy_valid'], label='LION')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('valid accuracy widerestnet')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(10, 6))

plt.plot(GSAMv3['epoch'], GSAMv3['accuracy_valid'], label='GSAM')
plt.plot(LIONv3['epoch'], LIONv3['accuracy_valid'], label='LION')
plt.plot(SWAv3['epoch'], SWAv3['accuracy_valid'], label='SWA')
plt.plot(SGDv3['epoch'], SGDv3['accuracy_valid'], label='SGD')
plt.plot(SAMv3['epoch'], SAMv3['accuracy_valid'], label='SAM')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()

# %%
df = SAMv3


plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['accuracy_train'], label='Accuracy Train')
plt.plot(df['epoch'], df['accuracy_valid'], label='Accuracy Valid')

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# plt.ylim(0, 100)

plt.grid(True)
plt.show()


plt.figure(figsize=(10, 6))
plt.plot(df['epoch'], df['loss_valid'], color='r', label='Loss Valid')

plt.plot(df['epoch'], df['loss_train'], color='g', label='Loss Train')

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.grid(True)
plt.show()



plt.figure(figsize=(10, 6))

plt.plot(df['epoch'], df['lr'])

plt.xlabel('Epoch')
plt.ylabel('learning rate')
plt.legend()

plt.xlim(0, 50)

plt.grid(True)
plt.show()
